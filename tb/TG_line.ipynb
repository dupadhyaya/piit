# %% [markdown]
# # Tableau Graph -
# - https://help.tableau.com/current/pro/desktop/en-us/buildexamples_line.htm

# %% [markdown]
# ![image.png](attachment:20b9bf41-0487-4ce0-8c40-caedd2896127.png)

# %% [markdown]
# ![image.png](attachment:d5a6fef6-3551-4212-a623-b1ab53a92e5c.png)

# %% [markdown]
# ![image.png](attachment:7018f918-d66b-4a6a-887c-2045e2509585.png)

# %% [markdown]
# ![image.png](attachment:4bbc8497-26e4-434d-9b2e-af7018118f12.png)

# %% [markdown]
# ![image.png](attachment:5a5030a4-6bb1-4d7c-95f5-b802f87efc62.png)
