# %% [markdown]
# # Tableau - Scatter Plot
# - https://help.tableau.com/current/pro/desktop/en-us/buildexamples_scatter.htm
# - https://www.youtube.com/watch?v=cOEar3BZeic

# %% [markdown]
# ![image.png](attachment:30ee0fe9-28d1-4e4a-8aab-6dbb7faaa410.png)
