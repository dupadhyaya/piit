# %% [markdown]
# # Tableau - Graph - Bullet
# - https://help.tableau.com/current/pro/desktop/en-us/qs_bullet_graphs.htm

# %% [markdown]
# ![image.png](attachment:857f5f3a-bd70-4020-be34-4571ec2697cc.png)
