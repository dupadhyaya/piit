# %% [markdown]
# # Tableau - General
# - Setup Files
# - Installation Instructions
# - Tableau Public

# %% [markdown]
# # My Help Files
# - https://docs.google.com/spreadsheets/d/1C8sOBppRgAzd4KqHE1kK-1ROyuzmhhVpe5FOGFb0DbU/edit?gid=1837917565#gid=1837917565

# %% [markdown]
# ## Tableau General
# - Licenscing
#     - https://www.tableau.com/pricing
# - Products
#     - https://www.tableau.com/products/tableau

# %% [markdown]
# ## Tableau Public
# - https://www.tableau.com/products/public/download
# - https://www.youtube.com/watch?v=fBLJj2AlN9U

# %% [markdown]
# ## DataSets
# - Tableau Sample Datasets
#     -  https://public.tableau.com/app/learn/sample-data
#     -  .
# - Superstore
#     -  https://public.tableau.com/app/sample-data/sample_-_superstore.xls
#     -  https://github.com/dupadhyaya/piit/blob/main/data/sample_-_superstore.xls (mygit)
#     -  CSV Links
#         -  Orders : https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_orders.csv
#         -  Returns : https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_returns.csv
#         -  People : https://github.com/dupadhyaya/piit/blob/main/data/superstore_people.csv

# %%
## Load Data in Tableau
- https://help.tableau.com/current/guides/get-started-tutorial/en-us/get-started-tutorial-connect.htm
- https://medium.com/@ankurdhamija83/how-to-load-your-first-dataset-in-tableau-f3404b39e2e0

# %% [markdown]
# ## Tableau Dashboards
# - Superstore Data
#     - https://medium.com/@ankurdhamija83/how-to-load-your-first-dataset-in-tableau-f3404b39e2e0
#     - https://www.linkedin.com/pulse/exploratory-data-analysis-sample-superstore-dataset-using-kr-pal-fky1f/
#     - https://public.tableau.com/app/profile/p.padham/viz/SuperstoreDashboard_16709573699130/SuperstoreDashboard
#     - https://www.tableau.com/data-insights/dashboard-showcase/superstore
#     - https://github.com/Mr-Lokesh/Tableau-Sample-Superstore-Dashboard
#     - https://public.tableau.com/app/profile/waqar.ahmed.shaikh/viz/SuperstoreOverviewDashboard_17090332693110/HomeLM
#     - https://youtu.be/FzHmdVEHFWc
#     - linkedin.com/pulse/superstore-analytics-dashboard-using-tableau-data-70-putri-kurnia-yzdcc
#     - https://www.tableau.com/solutions/gallery/superstore
#     - https://www.phdata.io/blog/interactive-superstore-tableau-dashboard-example/
#     - https://www.spec-india.com/live-bi-visualization/tableau-superstore-dashboard
#     - https://public.tableau.com/app/profile/fathima.shanavas/viz/SuperStoreDashboard-Final/DesignedDashboard
#     - https://xi-n-yi.github.io/mysite/portfolio/Tableau%20Dashboard%20Project%20-%20SuperStore%20Sales/
#     - https://github.com/KristiBischoff/Superstore-Analysis-Tableau-Dashboards
#     - https://medium.com/@preranamatya/building-tableau-dashboard-superstore-dataset-project-2505fc6cee6d
#     - https://public.tableau.com/app/profile/tobiloba.babajide/viz/SuperStoreDashboard_17151044281660/ExecutiveSummary
#     - https://public.tableau.com/app/profile/tobiloba.babajide/viz/SampleSuperstoreDashboard_17470960865060/HomePage

# %% [markdown]
# ## Tableau Graphs

# %% [markdown]
# ## Tableau Topics
# - Tableau Menu
# - How to load Data
# - How to Change Data Type
# - Understanding Dimensions and Measures
# - How to Filter data from the source
# - How to create first graph - Sheet
# - How to create a Dashboard with common settings (Floating, View Area, Title, Border, Apply Filters to all sheets etc)
# - How to create a story from Sheets and Dashboard - ?
# - How to create different types of graph
#     - Bar, Line, Bar & Line, Scatter, Pie
#     - Boxplot, Histogram
#     - Area, Treemap, Text, Heatmap, Highlight
#     - Geomap,
#     - Others ---
# - How to use part of sheet - Marks, Columns, Rows, Filter, Show me
# - How to create Calculated Field
# - How to create Parameter - ?
# - How to create a Group & Set - ?
# - How to Add Extensions - ?
# - How to Change sheetname, title, axis, format of parts of the graph
# - How to adjust the graph in the view, dashboard
# - How to use action filter in Dashboard (Hover, Select)
# - How to publish workbook to Tableau  public (show sheets tab)
# - How to perform Quick Table Calculation
# - How to create a Hierachy of fields (Geo map)
# - How to use LOD (Level of Detail) - ?
# - How to Edit the Axis, Format the labels, borders of the sheet
# - How to use Analytics - Reference Lines/ Bands ?
# - How to connect Tableau to MySQL (?), Excel, CSV etc
# - How to add Row and Column Totals and Sub Total - ?
# - How to join Tables ?
# - How to connect multiple data sources into workbook (Blend) -?
