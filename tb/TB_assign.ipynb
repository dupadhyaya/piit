# %% [markdown]
# # Tableau : Assignment/ Practise Exercises
# - Analytical Questions
# - 24 Jun 2026

# %% [markdown]
# ## Superstore Data Set
# - Orders : https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_orders.csv

# %% [markdown]
# # Analytics Qs
# ![image.png](attachment:dd4b777e-1f94-42ee-bae0-b4da6d680600.png)
# ![image.png](attachment:fb5471fd-086b-4b62-a32c-462c2465e77c.png)

# %% [markdown]
# # Activities (Goal-> Area->Query->Graphs)
# - Understand Business Performance (Sales Performance)
#     - What are the total sales, profit, and quantity sold over time?
#     - Line chart (sales/profit trend over time)
# - Understand Business Performance Sales Performance
#     - Which product categories contribute most to total sales and profit?
#     - Bar chart (category/sub-category contribution)
# - Understand Business Performance	Sales Performance	How do sales and profit vary by region or segment?	Map (sales/profit by state or region)
# Identify high-value customers and understand buying behavior.	Customer Analysis	Who are the top 10 customers by sales or profit?	Pareto chart (top customers contributing to 80% of sales
# - Identify high-value customers and understand buying behavior.	Customer Analysis	How many customers are repeat buyers?	Bar chart or scatter plot (customer sales vs. profit)
# - Identify high-value customers and understand buying behavior.	Customer Analysis	What is the average order value by customer segment?	Segment-wise customer distribution (tree map or pie chart)
# - Analyze which products drive growth and which hurt profitability.	Product & Category 	Which subcategories have the highest profit margins?	Scatter plot (sales vs. profit per product)
# - Analyze which products drive growth and which hurt profitability.	Product & Category 	Which products have negative profit despite high sales?	Heat map (category vs. region by sales)
# - Analyze which products drive growth and which hurt profitability.	Product & Category 	What’s the sales trend of top 5 subcategories over the last year?	Line chart (sales trend per sub-category)
# - Explore performance across regions and states.	Regional & Geographic	Which regions are most profitable?	Filled map or symbol map (sales/profit by geography)
# - Explore performance across regions and states.	Regional & Geographic	How do discounts and shipping costs vary by state?	Dual-axis map (profit ratio overlay)
# - Explore performance across regions and states.	Regional & Geographic	What is the average delivery time per region?	Bar chart (discount or shipping cost by region)
# - Spot patterns, seasonality, and growth opportunities	Time-Series & Trend	How have sales and profit changed month over month or year over year?	Line chart (sales trend over time)
# - Spot patterns, seasonality, and growth opportunities	Time-Series & Trend	Are there seasonal spikes in orders or profits?	Dual-axis line chart (sales vs. profit trends)
# - Spot patterns, seasonality, and growth opportunities	Time-Series & Trend	What is the moving average of sales for the last 3 months?	Forecast chart using Tableau’s analytics pane
# - Understand how discounting affects profit.	Profitability & Discount 	How do profit margins change with discount rates?	Scatter plot (discount vs. profit)
# - Understand how discounting affects profit.	Profitability & Discount 	What is the relationship between discount and sales volume?	Box plot (profit distribution by discount level)
# - Understand how discounting affects profit.	Profitability & Discount 	Which segments or regions lose profit due to discounts?	Dual-axis bar chart (sales and profit comparison)
# - Evaluate operational efficiency.	Shipping & Delivery	What are the average shipping days by ship mode?	Bar chart (average delivery days by ship mode)
# -Evaluate operational efficiency.	Shipping & Delivery	How do shipping costs affect overall profitability?	Map (average delivery time by region)
# - Evaluate operational efficiency.	Shipping & Delivery	Which regions experience the longest delivery times?	Line chart (shipping cost trend)

# %% [markdown]
# ## Tableau Assignment - 2 : Bookshop Dataset
# - Data
# - https://help.tableau.com/current/pro/desktop/en-us/bookshop_data.htm
# - Analytical Qs
#     - What books are the most popular? The least popular? Is that based on sales, reviews, checkouts, or another metric?
#     - Who was the youngest debut author? Who was the oldest?
#     - Do some publishing houses seem to specialize in any way?
#     - What was the longest time between editions of the same book?
#     - Are there any seasonal trends for sales? What about checkouts? Do any titles or genres have seasonal fluctuations?
#     - Are there any correlations between checkouts, print run size, book review ratings, and sales volume?
#     - Do the authors who spend the most time writing have the most successful books? Do they have the highest page count?
#     - When are most books published? Are there any anomalies?
#     - Are there any trends for genre, format, and price?
#     - What sort of distributions do the ratings have? Do those distributions vary by book? By genre? Do they seem to align with awards?
#     - How would you calculate the sales price, given that there is sometimes—but not always—a discount given at the time of sale?
#     - Do sales approximate the Pareto principle?
#     - Are there any patterns in the discounts?
#     - Do any tables in particular appear to have dirty data?

# %% [markdown]
# ## Other Links
# - https://www.cittabase.com/turning-retail-data-into-executive-insights-with-tableau/
