# %%
# Tableau - Bar Plot
-
-
- https://help.tableau.com/current/pro/desktop/en-us/buildexamples_bar.htm

# %% [markdown]
# ![image.png](attachment:5d4a1e94-65cb-4231-bfaa-60dd4dc802f1.png)

# %% [markdown]
# ![image.png](attachment:13e02b8b-0f68-4691-9e53-e87bf8f90ed4.png)

# %% [markdown]
# ![image.png](attachment:8338bdcc-5575-418e-8918-fd56526c6966.png)
