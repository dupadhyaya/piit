# %% [markdown]
# # AI in jupyter

# %%
#!pip install jupyter-ai

# %%
# !jupyter --paths
# Out:
# config:
#     /Users/du/.jupyter
#     /Users/du/.local/etc/jupyter
#     /Users/du/anaconda3/etc/jupyter
#     /usr/local/etc/jupyter
#     /etc/jupyter
# data:
#     /Users/du/Library/Jupyter
#     /Users/du/.local/share/jupyter
#     /Users/du/anaconda3/share/jupyter
#     /usr/local/share/jupyter
#     /usr/share/jupyter
# runtime:
#     /Users/du/Library/Jupyter/runtime
