# %% [markdown]
# # AI Assignment : Assignment: Explore and Compare AI Tools

# %% [markdown]
# ## Objective
# - Explore popular AI tools and understand their features, strengths, limitations and practical applications.
#
# ## Task
# - Working individually or in groups of 2–3 students, select 4–6 AI tools from the same category (e.g., AI Assistants, Presentation Tools, Coding Tools, Image Generation, Research Tools).

# %% [markdown]
# ## Prepare a 10–15 minute presentation covering the following points for each tool:
# 1. Name of the AI tool and the company behind it.
# 2. Main features and typical use cases.
# 3. Free vs. paid licensing (pricing, if available).
# 4. Availability on:
#     * Web
#     * Windows/macOS
#     * Android/iOS
# 5. Demonstrate one common task using the same prompt on at least 2 tools.
# 6. Strengths and limitations.
# 7. How can this tool be used for Data Analysis?
#     * Can it analyse Excel/CSV files?
#     * Can it generate charts and visualisations?
#     * Can it write SQL, Python or R code?
#     * Can it summarise insights from data?
#     * Can it help create dashboards or reports?
#     * Mention one real-life data analytics use case.
# 8. A comparison table highlighting the differences.
# 9. Your recommendation:
#     * Best for students
#     * Best for professionals
#     * Best free tool
#     * Overall best tool

# %%
## Suggested AI Tools

### General AI Assistants

* ChatGPT
* Google Gemini
* Claude
* Microsoft Copilot
* Perplexity
* Grok

### Presentation & Design

* Canva AI
* Gamma
* Beautiful.ai
* Microsoft Designer
* Adobe Express

Coding

* GitHub Copilot
* Cursor
* Replit AI
* Gemini Code Assist

Research

* NotebookLM
* Perplexity
* SciSpace
* Elicit
* Consensus

Image & Video

* DALL·E
* Midjourney
* Adobe Firefly
* Runway
* Pika

# %%
Deliverables

* 8–10 slide presentation (PowerPoint or Google Slides)
* 10–15 minute presentation
* Include references to the official websites used for your research.
