# %%
# Student Queries

# %% [markdown]
# # Final Activities
# - Quiz - 06 Dec 25
# - Final Class - 07 Dec 25
# - Group of 2 students (mutually done) - List to be finalised
# - Recording of Videos in which one Student becomes Interviewer and other becomes Candidate.
#     - Interview will ask for self introduction and any other interview questions
#     - In 2nd part of video, Interviewer will ask for standard question as provided
# - Self Introduction
#     - https://docs.google.com/document/d/1-PzB7in9f0HSCStCpwJqhN1aG2m6IBYxYbk_erm1BMI/edit?tab=t.0
# - Interview Questions
#     - https://github.com/dupadhyaya/piit/blob/main/intQs/data_analyst_interview_questions.pdf
# - Both the videos will be uploaded into their respective google accounts and shared with PIIT team
# - After Evaluation of Quiz, Videos further support of placement to be provided. Personal counselling to be done if required
# - This can happen once all videos have been uploaded and links provided to the PIIT team

# %% [markdown]
# ## 30 Nov 2025
# - Aggregate function in SQL (with Group by) --- Muhammad, Nayeema
#     - piit/sql/sqlD4A_gb.ipynb
# - For Loop ----- Bijata
#     - piit/py/others/loops.ipynb
# - Story telling ---- Huma
#     - piit/misc/storyTelling.ipynb
# - Def function ---- Sultana
#     - piit/py/others/functions.ipynb
# - Creating report to the Manager ----- Jugurtha
#     - piit/misc/reportWriting.ipynb
# ## Quiz Test
# - https://docs.google.com/forms/d/e/1FAIpQLSflRf3hmqGMZVeSfgH6W6pfw2KFGyde1i0SXcJXZgpvdNgDfA/viewform
# ## Interview Questions
# - General : https://github.com/dupadhyaya/piit/blob/main/intQs/intQgen.ipynb
# - Python : https://github.com/dupadhyaya/piit/blob/main/intQs/intQpy.ipynb
# - SQL : https://github.com/dupadhyaya/piit/blob/main/intQs/intQsql.ipynb
# - XLS : https://github.com/dupadhyaya/piit/blob/main/intQs/intQxlgs.ipynb
# - Tableau : https://github.com/dupadhyaya/piit/blob/main/intQs/intQstableau.ipynb

# %% [markdown]
# ## 29 Nov 2025
# - Advance group by
# - CTE (WITH clause) & Recursive CTE
# - Window functions
# - Indexing

# %% [markdown]
# ## 16 Nov 2025
# - Bijata: Hypothesis testing
# - HA: T-test, Anova test and Regression Analysis
# - Ratiba: Can we use Bind for plotting in R?

# %% [markdown]
# ## 15 Nov 2025
# - Mohammad: Link with SQL
# - Dj : Visualization, reports in R and GGPLOT.
# - Mandal: How to create a Dataframe
