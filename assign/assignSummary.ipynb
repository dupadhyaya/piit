# %% [markdown]
# ## Assignment Summary

# %% [markdown]
# ## General
# - https://github.com/dupadhyaya/piit/blob/main/assign/GEN_assign1.ipynb

# %% [markdown]
# ## Python
# ### Assignment : PY/01
#     - https://github.com/dupadhyaya/piit/blob/main/assign/PY_assign1.ipynb
# ### Assignment : PY/02
#     - https://github.com/dupadhyaya/piit/blob/main/assign/PY_assign2.ipynb

# %% [markdown]
# ## MySQL
# ### Assignment : SQL/01
#     - https://github.com/dupadhyaya/piit/blob/main/assign/SQL_assign1.ipynb

# %% [markdown]
# ## Tableau
# - https://github.com/dupadhyaya/piit/blob/main/assign/TB_assign1.ipynb
# - https://github.com/dupadhyaya/piit/blob/main/assign/TB_assign2.ipynb

# %% [markdown]
# ## Excel/GS
# ### Assignment : GS/01
#     - https://docs.google.com/spreadsheets/d/1tTEalsKYhP_Wl8-ddSx6opUAccwqbt2OzWWzEnr8pIc/edit
#     - Make a duplicate of this GS. Rename it: PIIT2 - GS Assignment - xxxxx
# (xxx- first name)
#     - Give commentator rights to everyone. Share it with PIIT Team/ Mandal
# - ### Assignment : GS/02
#     - https://github.com/dupadhyaya/piit/blob/main/assign/GS_assign2.ipynb
