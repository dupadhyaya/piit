# %% [markdown]
# # Graphs using ggplot library in Python
# - https://www.geeksforgeeks.org/data-visualization/data-visualization-using-plotnine-and-ggplot2-in-python/
# - https://github.com/DUanalytics/pyJupyter/tree/master/04C-ggplot
# - https://realpython.com/ggplot-python/
# - https://plotnine.org/
# - https://plotnine.org/reference/geom_col.html#plotnine.geom_col

# %%
#pip install plotnine

# %%
import numpy  as np
import pandas as pd
from pydataset import data
import matplotlib.pyplot as plt
from plotnine import ggplot,aes
from plotnine import geom_point, geom_col, geom_histogram, geom_boxplot, facet_grid, labs  #imp

# %%
mtcars = data('mtcars')
mtcars.head(2)
# Out:
#                 mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4      21.0    6  160.0  110   3.9  2.620  16.46   0   1     4     4
# Mazda RX4 Wag  21.0    6  160.0  110   3.9  2.875  17.02   0   1     4     4

# %%
ggplot(mtcars) + aes(x="wt", y="mpg", size="hp", color='gear')  + geom_point()

# %%
ggplot(mtcars) + aes(y="mpg")  + geom_boxplot()

# %%
ggplot(mtcars) + facet_grid("~ gear") + aes(x='wt',y='mpg', color='am') + labs(x='Weight', y='Mileage') + geom_point()

# %%
ggplot(mtcars) + aes(x="mpg") + geom_histogram(bins=5, color='green', fill='yellow')

# %%
from plotnine import *

# %%
(ggplot(mtcars, aes(x="wt", y="mpg", fill="gear"))     + geom_point() )

# %%
( ggplot(mtcars.astype({'am':'category'}), aes(x="gear", fill='am'))  + geom_bar(position="stack") + facet_grid("~ cyl"))
