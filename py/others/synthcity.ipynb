# %% [markdown]
# # Synthetic Data synthcity
# - https://pypi.org/project/synthcity/

# %%
#pip install synthcity

# %%
#List the available general-purpose generators
from synthcity.plugins import Plugins

Plugins(categories=["generic", "privacy"]).list()
# Out:
# Disabling PyTorch because PyTorch >= 2.4 is required but found 2.2.2
# PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from synthcity.plugins import Plugins
#       3 Plugins(categories=["generic", "privacy"]).list()
#
# File ~/anaconda3/lib/python3.12/site-packages/synthcity/plugins/__init__.py:9
#       6 from pydantic import validate_arguments
#       8 # synthcity absolute
# ----> 9 from synthcity.plugins.core.plugin import Plugin, PluginLoader  # noqa: F401,E402
#      11 def_categories = [
#      12     "generic",
#      13     "privacy",
#    (...)
#      18     "debug",
#      19 ]
#      20 plugins = {}
#
# File ~/anaconda3/lib/python3.12/site-packages/synthcity/plugins/core/plugin.py:16
#      14 # synthcity absolute
#      15 import synthcity.logger as log
# ---> 16 from synthcity.metrics.plots import plot_marginal_comparison, plot_tsne
#      17 from synthcity.plugins.core.constraints import Constraints
#      18 from synthcity.plugins.core.dataloader import (
#      19     DataLoader,
#      20     GenericDataLoader,
#    (...)
#      23     create_from_info,
#      24 )
#
# File ~/anaconda3/lib/python3.12/site-packages/synthcity/metrics/__init__.py:2
#       1 # synthcity relative
# ----> 2 from .eval import Metrics  # noqa: F401
#       3 from .weighted_metrics import WeightedMetrics  # noqa: F401
#
# File ~/anaconda3/lib/python3.12/site-packages/synthcity/metrics/eval.py:10
#       7 from pydantic import validate_arguments
#       9 # synthcity absolute
# ---> 10 from synthcity.plugins.core.dataloader import (
#      11     DataLoader,
#      12     GenericDataLoader,
#      13     create_from_info,
#      14 )
#      16 # synthcity relative
#      17 from .eval_detection import (
#      18     SyntheticDetectionGMM,
#      19     SyntheticDetectionLinear,
#      20     SyntheticDetectionMLP,
#      21     SyntheticDetectionXGB,
#      22 )
#
# File ~/anaconda3/lib/python3.12/site-packages/synthcity/plugins/core/dataloader.py:22
#      20 from synthcity.plugins.core.models.feature_encoder import DatetimeEncoder
#      21 from synthcity.utils.compression import compress_dataset, decompress_dataset
# ---> 22 from synthcity.utils.serialization import dataframe_hash
#      25 class DataLoader(metaclass=ABCMeta):
#      26     """
#      27     .. inheritance-diagram:: synthcity.plugins.core.dataloader.DataLoader
#      28         :parts: 1
#    (...)
#      67             The feature name that provides labels for downstream tasks.
#      68     """
#
# File ~/anaconda3/lib/python3.12/site-packages/synthcity/utils/serialization.py:9
#       7 import cloudpickle
#       8 import pandas as pd
# ----> 9 from opacus import PrivacyEngine
#      11 # The list of plugins that are not simply loadable with cloudpickle
#      12 unloadable_plugins: List[str] = [
#      13     "dpgan",  # DP-GAN plugin id not loadable with cloudpickle due to the DPOptimizer
#      14 ]
#
# File ~/anaconda3/lib/python3.12/site-packages/opacus/__init__.py:17
#       1 #!/usr/bin/env python3
#       2 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 from . import utils
# ---> 17 from .grad_sample import GradSampleModule, GradSampleModuleFastGradientClipping
#      18 from .privacy_engine import PrivacyEngine
#      19 from .version import __version__
#
# File ~/anaconda3/lib/python3.12/site-packages/opacus/grad_sample/__init__.py:32
#      30 from .layer_norm import compute_layer_norm_grad_sample  # noqa
#      31 from .linear import compute_linear_grad_sample  # noqa
# ---> 32 from .rms_norm import compute_rms_norm_grad_sample  # noqa
#      33 from .utils import (
#      34     get_gsm_class,
#      35     register_grad_sampler,
#      36     register_norm_sampler,
#      37     wrap_model,
#      38 )
#      41 __all__ = [
#      42     "GradSampleModule",
#      43     "GradSampleModuleFastGradientClipping",
#    (...)
#      51     "get_gsm_class",
#      52 ]
#
# File ~/anaconda3/lib/python3.12/site-packages/opacus/grad_sample/rms_norm.py:27
#      22 from opacus.utils.tensor_utils import sum_over_all_but_batch_and_last_n
#      24 from .utils import register_grad_sampler
# ---> 27 @register_grad_sampler(nn.RMSNorm)
#      28 def compute_rms_norm_grad_sample(
#      29     layer: nn.RMSNorm,
#      30     activations: List[torch.Tensor],
#      31     backprops: torch.Tensor,
#      32 ) -> Dict[nn.Parameter, torch.Tensor]:
#      33     """
#      34     Computes per sample gradients for RMSNorm
#      35
#    (...)
#      39         backprops: Backpropagations
#      40     """
#      41     activations = activations[0]
#
# AttributeError: module 'torch.nn' has no attribute 'RMSNorm'

# %%
from sklearn.datasets import load_diabetes
from synthcity.plugins import Plugins

X, y = load_diabetes(return_X_y=True, as_frame=True)
X["target"] = y

syn_model = Plugins().get("adsgan")

syn_model.fit(X)
