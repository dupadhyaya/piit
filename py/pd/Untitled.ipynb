# %%
import pandas as pd

# %%
import os

# %%
os.listdir('/Users/du/dup/analytics/data')
# Out:
# ['studentsX1.csv',
#  'MFGEmployees4.csv',
#  '.DS_Store',
#  'employees2.xlsx',
#  'students1.csv',
#  'pdftable.pdf',
#  'dataset_2025-08-16T11_40_29.251665198Z_DEFAULT_INTEGRATION_IMF.STA_QGDP_WCA_3.0.0.csv',
#  'attritionData.csv',
#  'pstudents.csv',
#  'WA_Fn-UseC_-HR-Employee-Attrition.csv',
#  'suroor.csv',
#  'sqldata1.csv',
#  'employees1.csv',
#  'sales_forecasting_data.xlsx',
#  'hrClustering.csv',
#  'pet.txt',
#  'stateCodes.csv',
#  'piitstudents.csv',
#  'Country_Codes_and_Names.xlsx',
#  'studentsX2.xlsx',
#  'mtcars.csv',
#  'VLOOKUP and HLOOKUP.xlsx',
#  'archive.zip',
#  'attrition.zip',
#  'studentsb2.csv',
#  'students_export.csv',
#  'HRDataset_v14.csv',
#  'hrdataset.zip',
#  'Real_Estate_Sales_2001-2023_GL.csv',
#  'deceptive-opinion.csv',
#  'subjectARdata.csv']

# %%
students = pd.read_csv('/Users/du/dup/analytics/data/students2b.csv')
students
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 students = pd.read_csv('/Users/du/dup/analytics/data/students2b.csv')
#       2 students
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
