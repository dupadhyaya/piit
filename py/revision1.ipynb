# %% [markdown]
# # Revision after a long time
# #14 Sep 25
# - work simultaneously with different domain
# - if you stop practising, you forget , it is tough restarting
# - vacation, used time for other activities

# %%
# Install if not already installed
#!pip install pydataset

# %%
# Import libraries
import pandas as pd  # data analysis
import matplotlib.pyplot as plt # make graphs
from pydataset import data # sample

# %%
', '.join(data().dataset_id)

# %%
data('iris').head()

# %%
data('sleep').head()

# %%
# Load the dataset
df = data('mtcars')

# %%
df.head(2)

# %%
df.tail(5)

# %%
df.shape

# %%
df.describe()

# %%
df.dtypes

# %%
df.info()

# %% [markdown]
# # Data Analysis
# - load data from different sources
# - save data into different formats
# - understand the data structures, how large, names of col,
# - missing values, inconsistencies, cleaning, transformation
# - sort
# - filter - conditions; search for string
# - slicing - select rows, cols on conditions
# - merge data - row, col
# - join
# - visualise- bar, pie, presentation, storytelling
# - outliers
# - groupby summaries, pivot
# - rotate data - long, wide
# - statistics - mean, median, mode, std, skewness, kurtosis, correlation, covariance
# - data distribution - normal,
# - sampling

# %%
df.groupby('cyl')['mpg'].mean().reset_index()

# %%
df['mpg'].hist(bins=10)
plt.xlabel("Miles per Gallon")
plt.ylabel("Frequency")
plt.title("Distribution of MPG in Cars")
plt.show()

# %%
plt.scatter(df['hp'], df['mpg'])
plt.xlabel("Horsepower")
plt.ylabel("Miles per Gallon")
plt.title("MPG vs Horsepower")
plt.show()
