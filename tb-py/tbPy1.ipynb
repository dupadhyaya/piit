# %%
# Tableau - Python Comparison

# %% [markdown]
# # Data from Online CSV in Git Hub - Superstore Data Set

# %%
import pandas as pd
import openpyxl

# %%
csv_orders_url = 'https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_orders.csv'
csv_returns_url = 'https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_returns.csv'
csv_people_url = 'https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_people.csv'
print(csv_orders_url, '\n', csv_returns_url ,'\n', csv_people_url)
# Out:
# https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_orders.csv
#  https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_returns.csv
#  https://raw.githubusercontent.com/dupadhyaya/piit/refs/heads/main/data/superstore_people.csv

# %%
# Read the CSV file into a DataFrame
orders = pd.read_csv(csv_orders_url)
orders.shape
# Out:
# (9994, 21)

# %%
returns = pd.read_csv(csv_returns_url)
returns.shape
# Out:
# (296, 2)

# %%
people = pd.read_csv(csv_people_url)
people.shape
# Out:
# (4, 2)
