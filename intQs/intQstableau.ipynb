# %% [markdown]
# # Interview Qs - Tableau

# %% [markdown]
# - What is Tableau, and why is it used?
# - What are the different Tableau products (Desktop, Prep, Public, Server, Online), and how do they differ?
# - What do Dimensions and Measures mean in Tableau?
# - What types of data sources can Tableau connect to? Give examples.
# - What is the difference between a worksheet, dashboard, and story?
# - What types of joins are available in Tableau?
# - What is the difference between a LIVE connection and an EXTRACT?
# - What is a calculated field? Give a simple example.
# - What is the difference between a discrete and a continuous field?
# - What types of filters exist in Tableau? (Extract, Data Source, Context, Quick filters, etc.)
# - What is the difference between a filter and a parameter?
# - What is a hierarchy in Tableau, and why is it useful?
# - What is the purpose of Show Me, and how does it help users?
# - How do you create a dual-axis chart, and when would you use it?
# - What are Marks in Tableau? What can you customise using the Marks card?
# - What are groups and sets in Tableau? How are they different?
# - How do you create a simple dashboard? Mention basic layout best practices.
# - Why are sorting and filtering important in visualisations?
# - What are tooltips? How can you customise them?
# - How do you publish a workbook to Tableau Server or Tableau Public?
